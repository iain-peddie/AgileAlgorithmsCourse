# %%
import sys
sys.path.append('.')
import CourseExamples
import SplineAlgorithms
import numpy as np
from matplotlib.pyplot import *
# set reloading so that when NacaCurves module changes under development
# changes are automatically noticed. (Why can't this be the default?)
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
def plotSnapshot(curve):
    """Plots the spline.
    
    Inputs
    ------
    controlPoints: [N*D] the control point on the spline
    dataPoints: [M*D] The data points a spline was fitted to
    predPoints: [O*D] The predicted points on the spline."""
    
    upperPoints = curve['upper']
    lowerPoints = curve['lower']
    allPoints = curve['anticlockwise']
    
    plot(upperPoints[:, 0], upperPoints[:, 1], 'bs')
    plot(lowerPoints[:, 0], lowerPoints[:, 1], 'gx')
    plot(allPoints[:, 0], allPoints[:, 1], 'ro')

# %%
curve = CourseExamples.generateExampleData(1)
plotSnapshot(CourseExamples.generateExampleData(1)
