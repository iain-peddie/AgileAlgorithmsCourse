# %%
import sys
sys.path.append('../src/')
import CourseExamples
import numpy as np
from matplotlib.pyplot import *
# set reloading so that when NacaCurves module changes under development
# changes are automatically noticed. (Why can't this be the default?)
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
data = CourseExamples.generateExampleData(1)
figure(figsize=(20,20))
upper = data['upper'];
lower = data['lower'];
camber = data['camber'];
anticlockwise = data['anticlockwise']
plot(upper[:,0], upper[:,1], 'b.')
plot(lower[:, 0], lower[:, 1], 'g.')
plot(camber[:, 0], camber[:, 1], 'rx' )
plot(anticlockwise[:,0], anticlockwise[:,1], 'cs')
axes().set_aspect('equal')
show()

# %%
data = CourseExamples.generateExampleData(2)
figure(figsize=(20,20))
upper = data['upper'];
lower = data['lower'];
camber = data['camber'];
anticlockwise = data['anticlockwise']
plot(upper[:,0], upper[:,1], 'b.')
plot(lower[:, 0], lower[:, 1], 'g.')
plot(camber[:, 0], camber[:, 1], 'rx' )
plot(anticlockwise[:,0], anticlockwise[:,1], 'cs')
axes().set_aspect('equal')
show()

# %%
data = CourseExamples.generateExampleData(3)
figure(figsize=(20,20))
upper = data['upper'];
lower = data['lower'];
camber = data['camber'];
anticlockwise = data['anticlockwise']
plot(upper[:,0], upper[:,1], 'b.')
plot(lower[:, 0], lower[:, 1], 'g.')
plot(camber[:, 0], camber[:, 1], 'rx' )
plot(anticlockwise[:,0], anticlockwise[:,1], 'cs')
axes().set_aspect('equal')
show()

# %%
data = CourseExamples.generateExampleData(3)
figure(figsize=(20,20))
upper = data['upper'];
lower = data['lower'];
anticlockwise = data['anticlockwise']
plot(upper[:,0], upper[:,1], 'b.')
plot(lower[:, 0], lower[:, 1], 'g.')
axes().set_aspect('equal')
show()
